# %% [markdown]
# # 1.3 Decontamination and doublet removal
#
# Author: Xuezhu Sunny Wang
#
# ## Dataset 📊
#
# - Read in the merged single cell object
#
# ## Steps overview 📒
#
# - Run DecontX and DoubletFinder
# - Do embedding with 20 principal components

# %%
# =========================================================
# Packages
# =========================================================
library(haven)
library(dplyr)
library(readxl)
library(ggplot2)
library(survival)
library(survminer)
library(scales)
library(tidyr)
library(writexl)
library(broom)
library(ggpubr)
library(mediation)

# =========================================================
# Helper functions replacing gtsummary
# =========================================================
fmt_p <- function(p) {
  if (is.na(p)) return(NA_character_)
  if (p < 0.001) return("<0.001")
  sprintf("%.3f", p)
}

fmt_num <- function(x, digits = 1) {
  ifelse(
    is.na(x),
    NA_character_,
    format(round(x, digits), nsmall = digits, trim = TRUE)
  )
}

summarize_continuous <- function(df, var, by) {
  gvals <- df[[by]]
  x <- df[[var]]

  groups <- sort(unique(gvals[!is.na(gvals)]))

  out_stats <- lapply(seq_along(groups), function(i) {
    g <- groups[i]
    xv <- x[gvals == g]
    xv <- xv[!is.na(xv)]
    if (length(xv) == 0) return(NA_character_)
    paste0(
      fmt_num(median(xv, na.rm = TRUE), 1),
      " (",
      fmt_num(min(xv, na.rm = TRUE), 1),
      "–",
      fmt_num(max(xv, na.rm = TRUE), 1),
      ")"
    )
  })
  names(out_stats) <- paste0("stat_", seq_along(groups))

  tmp <- df[, c(var, by), drop = FALSE]
  tmp <- tmp[complete.cases(tmp), , drop = FALSE]

  pval <- NA_real_
  if (nrow(tmp) > 1 && length(unique(tmp[[by]])) >= 2) {
    if (length(unique(tmp[[by]])) == 2) {
      pval <- tryCatch(
        wilcox.test(tmp[[var]] ~ as.factor(tmp[[by]]))$p.value,
        error = function(e) NA_real_
      )
    } else {
      pval <- tryCatch(
        kruskal.test(tmp[[var]] ~ as.factor(tmp[[by]]))$p.value,
        error = function(e) NA_real_
      )
    }
  }

  tibble(
    variable = var,
    level = NA_character_,
    type = "continuous",
    N = sum(!is.na(x)),
    !!!out_stats,
    p = fmt_p(pval)
  )
}

summarize_categorical <- function(df, var, by) {
  tmp <- df[, c(var, by), drop = FALSE]
  tmp <- tmp[complete.cases(tmp), , drop = FALSE]

  if (nrow(tmp) == 0) {
    return(tibble(
      variable = var,
      level = NA_character_,
      type = "categorical",
      N = 0,
      stat_1 = NA_character_,
      p = NA_character_
    ))
  }

  tmp[[var]] <- as.character(tmp[[var]])
  tmp[[by]]  <- as.character(tmp[[by]])

  levels_var <- sort(unique(tmp[[var]]))
  groups <- sort(unique(tmp[[by]]))

  tab <- table(tmp[[var]], tmp[[by]], useNA = "no")

  out <- lapply(seq_along(levels_var), function(i) {
    lev <- levels_var[i]
    row <- list(
      variable = if (i == 1) var else "",
      level = lev,
      type = "categorical",
      N = sum(tmp[[var]] == lev, na.rm = TRUE)
    )

    for (j in seq_along(groups)) {
      g <- groups[j]
      n <- if (lev %in% rownames(tab) && g %in% colnames(tab)) tab[lev, g] else 0
      denom <- sum(tab[, g])
      row[[paste0("stat_", j)]] <- if (denom > 0) {
        paste0(n, " (", sprintf("%.1f", 100 * n / denom), "%)")
      } else {
        NA_character_
      }
    }
    row
  }) %>% bind_rows()

  pval <- NA_real_
  if (nrow(tab) > 0 && ncol(tab) > 1) {
    pval <- tryCatch({
      chi <- suppressWarnings(chisq.test(tab))
      if (all(chi$expected >= 5)) {
        chi$p.value
      } else {
        fisher.test(tab)$p.value
      }
    }, error = function(e) NA_real_)
  }

  out$p <- c(fmt_p(pval), rep("", nrow(out) - 1))
  out
}

build_summary_table <- function(df, vars, by, force_continuous = NULL) {
  res <- lapply(vars, function(v) {
    x <- df[[v]]
    treat_as_cont <- FALSE

    if (!is.null(force_continuous) && v %in% force_continuous) {
      treat_as_cont <- TRUE
    } else if (is.numeric(x)) {
      treat_as_cont <- TRUE
    }

    if (treat_as_cont) {
      summarize_continuous(df, v, by)
    } else {
      summarize_categorical(df, v, by)
    }
  })

  bind_rows(res)
}

rename_stat_columns <- function(tbl, labels) {
  stat_cols <- grep("^stat_", names(tbl), value = TRUE)
  if (length(stat_cols) != length(labels)) {
    stop("Number of labels must match number of stat columns.")
  }
  names(tbl)[match(stat_cols, names(tbl))] <- labels
  tbl
}

build_regression_table <- function(model, exponentiate = FALSE) {
  broom::tidy(model, conf.int = TRUE, exponentiate = exponentiate) %>%
    mutate(
      estimate = round(estimate, 3),
      conf.low = round(conf.low, 3),
      conf.high = round(conf.high, 3),
      p.value = vapply(p.value, fmt_p, character(1)),
      effect = paste0(estimate, " (", conf.low, ", ", conf.high, ")")
    ) %>%
    dplyr::select(term, effect, p.value)
}

# =========================================================
# Read data
# =========================================================
uni_df <- read_excel("./uni_df.xlsx")
nrow(uni_df) # 831

# =========================================================
# Baseline dFLC
# =========================================================
ggplot(uni_df, aes(x = dFLC)) + 
  geom_histogram(bins = 50) + 
  theme_classic()

df_sub <- uni_df %>%
  filter(!is.na(productive_IgH), !is.na(dFLC))

wilcox.test(dFLC ~ productive_IgH, data = df_sub)

ggplot(df_sub, aes(x = factor(productive_IgH), y = dFLC, fill = factor(productive_IgH))) +
  geom_violin(trim = FALSE, alpha = 0.6) +
  geom_boxplot(width = 0.1, outlier.shape = NA) +
  scale_y_log10() +
  stat_compare_means(method = "wilcox.test") +
  theme_classic()

#medians <- df_sub %>%
#  group_by(M_type_bin) %>%
#  summarise(med = median(dFLC, na.rm = TRUE), .groups = "drop")

#ggplot(df_sub, aes(x = factor(M_type_bin), y = dFLC, fill = factor(M_type_bin))) +
#  geom_violin(trim = FALSE, alpha = 0.6) +
#  geom_boxplot(width = 0.1, outlier.shape = NA) +
#  stat_summary(fun = median, geom = "point", size = 3, color = "red") +
#  geom_text(
#    data = medians,
#    aes(x = factor(M_type_bin), y = med, label = round(med, 1)),
#    vjust = -1, size = 4
#  ) +
#  scale_y_log10() +
#  theme_classic()

# =========================================================
# Baseline table by productive_IgH
# =========================================================
desired_order <- c(
  "Sex", "Age", "Age≥65", "AL isotype (1=λ)", "productive_IgH", "t(11;14)","Sx_Dx",
  "Involved Organs (n)", "Organs>2", "Cardiac involvement", "Renal involvement", "Hepatic involvement",
  "BMPC (%)", "BMPC>10", "dFLC", "dFLC≥180",
  "Mayo04", "Mayo04III", "Mayo04IIIb","Mayo12","Mayo12III_IV",
  "NYHA", "NYHA3/4", "NT-ProBNP(pg/mL)", "NTproBNP>8500", "BNP (ng/L)",
  "cTnl (ug/L)", "cTnI>0.1", "LVPW (mm)", "IVS (mm)", "EF (%)", "EF < 50",
  "eGFR", "eGFR<50", "24hUP (g)", "24hUP≥5g", "Albumin (g/L)", "Alb<30",
  "treat", "Dara firstline", "Bort firstline", "Ven firstline"
)

baseline_vars <- intersect(desired_order, names(uni_df))
baseline_vars

tbl1 <- build_summary_table(
  df = uni_df,
  vars = baseline_vars,
  by = "productive_IgH",
  force_continuous = c("Involved Organs (n)")
)

tbl1

# =========================================================
# Baseline table by cardiac involvement
# =========================================================
desired_order <- c(
  "Sex", "Age", "Age≥65", "AL isotype (1=λ)", "productive_IgH", "t(11;14)",
  "Cardiac involvement", "Renal involvement", "Hepatic involvement",
  "BMPC (%)", "BMPC>10", "dFLC", "dFLC≥180",
  "eGFR", "eGFR<50", "24hUP (g)", "24hUP≥5g", "Albumin (g/L)", "Alb<30",
  "Dara firstline", "Bort firstline", "Ven firstline"
)

baseline_vars <- intersect(desired_order, names(uni_df))

tbl2 <- build_summary_table(
  df = uni_df,
  vars = baseline_vars,
  by = "Cardiac involvement"
)

tbl2

# =========================================================
# Create response variables
# =========================================================
uni_df <- uni_df %>%
  mutate(
    across(
      c(`3m HR`,`6m HR`,`12m HR`,`24m HR`),
      ~ ifelse(. %in% c("CR","VGPR","PR"), 1,
               ifelse(. %in% c("SD"), 0, NA)),
      .names = "{gsub(' HR','',.col)}_or"
    ),
    across(
      c(`3m HR`,`6m HR`,`12m HR`,`24m HR`),
      ~ ifelse(. %in% c("CR","VGPR"), 1,
               ifelse(. %in% c("PR","SD"), 0, NA)),
      .names = "{gsub(' HR','',.col)}_vgpr"
    ),
    across(
      c(`3m HR`,`6m HR`,`12m HR`,`24m HR`),
      ~ ifelse(. %in% c("CR"), 1,
               ifelse(. %in% c("VGPR","PR","SD"), 0, NA)),
      .names = "{gsub(' HR','',.col)}_cr_only"
    ),
    across(
      starts_with("cardiac_"),
      ~ ifelse(. %in% c("CR","VGPR","PR"), 1,
               ifelse(. %in% c("SD"), 0, NA)),
      .names = "car_{.col}_or"
    ),
    across(
      starts_with("cardiac_"),
      ~ ifelse(. %in% c("CR","VGPR"), 1,
               ifelse(. %in% c("PR","SD"), 0, NA)),
      .names = "car_{.col}_vgpr"
    )
  )

# =========================================================
# Response summary table by productive_IgH
# =========================================================
response_vars <- c(
  "best_hema_resp", "hema_or", "hema_vgpr", "hema_cr_only",
  "3m_or","6m_or","12m_or","24m_or",
  "3m_vgpr","6m_vgpr","12m_vgpr","24m_vgpr",
  "3m_cr_only","6m_cr_only","12m_cr_only","24m_cr_only",
  "car_cardiac_12m_or","car_cardiac_24m_or",
  "car_cardiac_12m_vgpr","car_cardiac_24m_vgpr"
)

response_vars <- intersect(response_vars, names(uni_df))

tbl3 <- build_summary_table(
  df = uni_df,
  vars = response_vars,
  by = "productive_IgH"
)

tbl3 <- tbl3 %>%
  mutate(
    variable = recode(
      variable,
      "best_hema_resp" = "Best Heme Response",
      "hema_cr_only" = "CR Rate",
      "hema_or" = "ORR",
      "hema_vgpr" = "≥VGPR rate"
    )
  )

# rename group columns if there are exactly 2 groups
stat_cols_tbl3 <- grep("^stat_", names(tbl3), value = TRUE)
if (length(stat_cols_tbl3) == 2) {
  tbl3 <- rename_stat_columns(
    tbl3,
    labels = c("LC only (N=407)", "IgH prod (N=373)")
  )
}

tbl3

# =========================================================
# Hematologic response stacked bar plot
# =========================================================
plot_long <- uni_df %>%
  filter(!is.na(`productive_IgH`)) %>%   
  dplyr::select(`productive_IgH`, `3m HR`, `6m HR`, `12m HR`, `24m HR`) %>%
  tidyr::pivot_longer(
    cols = c(`3m HR`, `6m HR`, `12m HR`, `24m HR`),
    names_to = "Time",
    values_to = "Response",
    names_pattern = "(.*) HR"
  ) %>%
  dplyr::mutate(
    Time = factor(Time, levels = c("3m", "6m", "12m", "24m")),
    Response = factor(Response, levels = c("PD","SD","PR","VGPR","CR"))
  )

plot_summary <- plot_long %>%
  filter(!is.na(Response)) %>%
  group_by(`productive_IgH`, Time, Response) %>%
  summarise(n = n(), .groups = "drop") %>%
  group_by(`productive_IgH`, Time) %>%
  mutate(
    total = sum(n),
    percent = n / total * 100
  ) %>%
  ungroup()

plot_n_orr <- plot_long %>%
  filter(!is.na(Response)) %>%
  group_by(`productive_IgH`, Time) %>%
  summarise(
    n = n(),
    ORR = mean(Response %in% c("CR","VGPR","PR")) * 100,
    .groups = "drop"
  )

ggplot(plot_summary, aes(x = Time, y = percent, fill = Response)) +
  geom_bar(stat = "identity", color = "black") +
  geom_text(
    aes(label = sprintf("%.0f%%", percent)),
    position = position_stack(vjust = 0.5),
    color = "white",
    size = 3.5,
    fontface = "bold"
  ) +
  geom_text(
    data = plot_n_orr,
    aes(x = Time, y = 104, label = sprintf("n = %d\nORR = %.1f%%", n, ORR)),
    inherit.aes = FALSE,
    size = 4,
    fontface = "bold",
    lineheight = 0.9
  ) +
  scale_fill_manual(
    values = c(
      "CR"   = "#1a9850",
      "VGPR" = "#91cf60",
      "PR"   = "#fee08b",
      "SD"   = "#fc8d59",
      "PD"   = "#d73027"
    ),
    name = "Hema Response"
  ) +
  facet_wrap(
    ~`productive_IgH`,
    labeller = labeller(
      `productive_IgH` = c(
        "0" = "LC",
        "1" = "IgH"
      )
    )
  ) +
  coord_cartesian(ylim = c(0, 106)) +
  theme_classic()



# =========================================================
# Regression and association analysis
# =========================================================
uni_df$log_dFLC <- log(uni_df$dFLC)

df2 <- uni_df %>% 
  dplyr::select(`Cardiac involvement`, productive_IgH, log_dFLC) %>% 
  na.omit()

lm(log(`NT-ProBNP(pg/mL)`) ~ productive_IgH + log_dFLC, data = uni_df)

summary(glm(`Cardiac involvement` ~ productive_IgH, data = df2, family = binomial))
summary(glm(`Cardiac involvement` ~ log_dFLC, data = df2, family = binomial))
summary(glm(`Cardiac involvement` ~ productive_IgH + log_dFLC, data = df2, family = binomial))
summary(lm(log_dFLC ~ productive_IgH, data = df2))

m1 <- glm(
  `Cardiac involvement` ~ 
    Age +
    productive_IgH +
    `BMPC>10` +
    log_dFLC +
    `eGFR<50` +
    `Alb<30` +
    `Dara firstline`,
  data = uni_df,
  family = binomial
)

table_m1 <- build_regression_table(m1, exponentiate = TRUE)
table_m1

# =========================================================
# Subset check
# =========================================================
df3 <- subset(uni_df, productive_IgH == 1)
nrow(df3)

summary(glm(`Cardiac involvement` ~ log_dFLC, data = df2, family = binomial))

# =========================================================
# Mediation analysis
# =========================================================
med.model <- lm(log_dFLC ~ productive_IgH, data = df2)

out.model <- glm(
  `Cardiac involvement` ~ productive_IgH + log_dFLC,
  data = df2,
  family = binomial
)

med.out <- mediate(
  med.model,
  out.model,
  treat = "productive_IgH",
  mediator = "log_dFLC",
  boot = TRUE,
  sims = 1000
)

summary(med.out)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: ggpubr
#
#
# Attaching package: ‘survminer’
#
#
# The following object is masked from ‘package:survival’:
#
#     myeloma
#
#
# Loading required package: MASS
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
# Loading required package: mvtnorm
#
# Loading required package: sandwich
#
# mediation: Causal Mediation Analysis
# Version: 4.5.1
# [1] 831
# Warning message:
# “Removed 42 rows containing non-finite outside the scale range (`stat_bin()`).”
# 	Wilcoxon rank sum test with continuity correction
#
# ...

# %%
library(dplyr)
library(tidyr)
library(purrr)
library(broom)
library(stringr)

# -----------------------------
# helper: pretty p-value
# -----------------------------
fmt_p <- function(p) {
  if (is.na(p)) return(NA_character_)
  if (p < 0.001) return("<0.001")
  sprintf("%.3f", p)
}

# -----------------------------
# helper: safe tests
# -----------------------------
get_p_cont <- function(data, var, by = "productive_IgH") {
  df <- data %>%
    dplyr::select(all_of(c(by, var))) %>%
    filter(!is.na(.data[[by]]), !is.na(.data[[var]]))

  if (nrow(df) == 0) return(NA_real_)
  if (length(unique(df[[by]])) < 2) return(NA_real_)
  if (length(unique(df[[var]])) < 2) return(NA_real_)

  out <- tryCatch({
    wilcox.test(df[[var]] ~ df[[by]])$p.value
  }, error = function(e) NA_real_)

  out
}

get_p_cat <- function(data, var, by = "productive_IgH") {
  df <- data %>%
    dplyr::select(all_of(c(by, var))) %>%
    filter(!is.na(.data[[by]]), !is.na(.data[[var]]))

  if (nrow(df) == 0) return(NA_real_)
  if (length(unique(df[[by]])) < 2) return(NA_real_)
  if (length(unique(df[[var]])) < 2) return(NA_real_)

  tab <- table(df[[var]], df[[by]])

  if (any(dim(tab) < 2)) return(NA_real_)

  out <- tryCatch({
    if (any(tab < 5)) {
      fisher.test(tab)$p.value
    } else {
      suppressWarnings(chisq.test(tab)$p.value)
    }
  }, error = function(e) NA_real_)

  out
}

# -----------------------------
# helper: detect variable type
# treat numeric with only 0/1 as categorical
# -----------------------------
detect_var_type <- function(x) {
  if (is.numeric(x)) {
    ux <- unique(x[!is.na(x)])
    if (length(ux) <= 2 && all(sort(ux) %in% c(0, 1))) {
      return("categorical")
    } else {
      return("continuous")
    }
  } else {
    return("categorical")
  }
}

# -----------------------------
# helper: summarize one continuous variable
# -----------------------------
summarise_continuous <- function(data, var, by = "productive_IgH", labels = NULL) {
  group_vals <- sort(unique(data[[by]][!is.na(data[[by]])]))

  stat_list <- lapply(group_vals, function(g) {
    x <- data %>%
      filter(.data[[by]] == g) %>%
      pull(all_of(var))

    tibble(
      group = as.character(g),
      value = if (all(is.na(x))) {
        NA_character_
      } else {
        sprintf(
          "%.1f (%.1f–%.1f)",
          median(x, na.rm = TRUE),
          min(x, na.rm = TRUE),
          max(x, na.rm = TRUE)
        )
      }
    )
  })

  stat_df <- bind_rows(stat_list) %>%
    pivot_wider(names_from = group, values_from = value)

  pval <- get_p_cont(data, var, by)

  tibble(
    Variable = if (!is.null(labels) && var %in% names(labels)) labels[[var]] else var,
    Level = ""
  ) %>%
    bind_cols(stat_df) %>%
    mutate(
      p_value = fmt_p(pval),
      sig = ifelse(!is.na(pval) & pval < 0.05, "*", "")
    )
}

# -----------------------------
# helper: summarize one categorical variable
# -----------------------------
summarise_categorical <- function(data, var, by = "productive_IgH", labels = NULL) {
  df <- data %>%
    filter(!is.na(.data[[var]]), !is.na(.data[[by]])) %>%
    mutate(
      .var = as.character(.data[[var]]),
      .by  = as.character(.data[[by]])
    )

  if (nrow(df) == 0) {
    return(
      tibble(
        Variable = if (!is.null(labels) && var %in% names(labels)) labels[[var]] else var,
        Level = NA_character_,
        p_value = NA_character_,
        sig = ""
      )
    )
  }

  group_vals <- sort(unique(df$.by))
  lvl_vals <- unique(df$.var)

  counts <- df %>%
    count(.var, .by, name = "n") %>%
    group_by(.by) %>%
    mutate(pct = 100 * n / sum(n)) %>%
    ungroup() %>%
    mutate(stat = sprintf("%d (%.1f%%)", n, pct)) %>%
    select(.var, .by, stat) %>%
    pivot_wider(names_from = .by, values_from = stat)

  pval <- get_p_cat(data, var, by)

  out <- counts %>%
    rename(Level = .var) %>%
    mutate(
      Variable = if (!is.null(labels) && var %in% names(labels)) labels[[var]] else var,
      p_value = ""
    ) %>%
    relocate(Variable, Level)

  if (nrow(out) > 0) {
    out$p_value[1] <- fmt_p(pval)
  }

  out <- out %>%
    mutate(
      sig = ""
    )

  if (nrow(out) > 0 && !is.na(pval) && pval < 0.05) {
    out$sig[1] <- "*"
  }

  out
}

# -----------------------------
# main table builder
# -----------------------------
make_summary_table <- function(data, vars, by = "productive_IgH", labels = NULL) {
  vars <- intersect(vars, names(data))

  pieces <- lapply(vars, function(v) {
    vtype <- detect_var_type(data[[v]])
    if (vtype == "continuous") {
      summarise_continuous(data, v, by, labels)
    } else {
      summarise_categorical(data, v, by, labels)
    }
  })

  out <- bind_rows(pieces)

  # add group Ns
  n_df <- data %>%
    filter(!is.na(.data[[by]])) %>%
    count(.data[[by]], name = "N") %>%
    mutate(group = as.character(.data[[by]]))

  group_vals <- sort(unique(data[[by]][!is.na(data[[by]])]))

  # rename group columns more nicely
  old_names <- intersect(as.character(group_vals), names(out))
  new_names <- paste0(old_names, " (N=", n_df$N[match(old_names, n_df$group)], ")")
  names(out)[match(old_names, names(out))] <- new_names

  out
}
# Out:
# Attaching package: ‘purrr’
#
#
# The following object is masked from ‘package:scales’:
#
#     discard

# %%
library(ggplot2)
library(dplyr)
library(tidyr)
library(viridisLite)

magma_cols <- viridisLite::magma(11)

# =========================================================
# 1) Build patient-level long response data from uni_df
# =========================================================
plot_long <- uni_df %>%
  filter(!is.na(productive_IgH)) %>%
  dplyr::select(productive_IgH, `3m HR`, `6m HR`, `12m HR`, `24m HR`) %>%
  pivot_longer(
    cols = c(`3m HR`, `6m HR`, `12m HR`, `24m HR`),
    names_to = "Time",
    values_to = "Response",
    names_pattern = "(.*) HR"
  ) %>%
  mutate(
    Time = factor(Time, levels = c("3m", "6m", "12m", "24m")),
    productive_IgH = as.character(productive_IgH),
    productive_IgH = recode(productive_IgH, "0" = "LC", "1" = "IgH"),
    productive_IgH = factor(productive_IgH, levels = c("LC", "IgH")),
    Response = factor(Response, levels = c("PD", "SD", "PR", "VGPR", "CR"))
  )

# =========================================================
# 2) Patient-level CR binary for proper testing
#    CR = 1, VGPR/PR/SD/PD = 0, missing stays NA
# =========================================================
cr_patient <- plot_long %>%
  mutate(
    CR_binary = case_when(
      Response == "CR" ~ 1,
      Response %in% c("VGPR", "PR", "SD", "PD") ~ 0,
      TRUE ~ NA_real_
    )
  ) %>%
  filter(!is.na(CR_binary), !is.na(productive_IgH), !is.na(Time))

# =========================================================
# 3) Wilcoxon test by Time on patient-level binary CR
#    (mathematically valid as a rank test on 0/1 values,
#     though Fisher/chi-square is usually more natural for binary outcomes)
# =========================================================
pval_df <- cr_patient %>%
  group_by(Time) %>%
  summarise(
    n_LC  = sum(productive_IgH == "LC"),
    n_IgH = sum(productive_IgH == "IgH"),
    CR_LC_pct  = mean(CR_binary[productive_IgH == "LC"],  na.rm = TRUE) * 100,
    CR_IgH_pct = mean(CR_binary[productive_IgH == "IgH"], na.rm = TRUE) * 100,
    p_value = tryCatch(
      wilcox.test(CR_binary ~ productive_IgH)$p.value,
      error = function(e) NA_real_
    ),
    .groups = "drop"
  ) %>%
  mutate(
    label = ifelse(
      is.na(p_value),
      "Wilcoxon p = NA",
      paste0("Wilcoxon p = ", signif(p_value, 3))
    )
  )

print(pval_df)

# =========================================================
# 4) Aggregated percentages for stacked bar plot
# =========================================================
plot_summary <- plot_long %>%
  filter(!is.na(Response)) %>%
  group_by(productive_IgH, Time, Response) %>%
  summarise(n = n(), .groups = "drop") %>%
  group_by(productive_IgH, Time) %>%
  mutate(
    total = sum(n),
    percent = n / total * 100
  ) %>%
  ungroup()

# n per facet/time
plot_n <- plot_long %>%
  filter(!is.na(Response)) %>%
  group_by(productive_IgH, Time) %>%
  summarise(
    n = n(),
    .groups = "drop"
  )

# =========================================================
# 5) Annotation data: repeat p-values into both facets
# =========================================================
y_top  <- max(plot_summary$percent, na.rm = TRUE)
y_n    <- y_top + 7
y_p    <- y_top + 14
y_lim  <- y_top + 22

pval_annot <- bind_rows(
  pval_df %>% mutate(productive_IgH = factor("LC", levels = c("LC", "IgH"))),
  pval_df %>% mutate(productive_IgH = factor("IgH", levels = c("LC", "IgH")))
)

plot_n_annot <- plot_n %>%
  mutate(label = paste0("n = ", n))

# =========================================================
# 6) Plot
# =========================================================
p <- ggplot(plot_summary, aes(x = Time, y = percent, fill = Response)) +
  geom_bar(stat = "identity", color = "black", width = 0.78) +
  geom_text(
    aes(label = sprintf("%.0f%%", percent)),
    position = position_stack(vjust = 0.5),
    color = "black",
    size = 4.0,
    fontface = "bold",
    lineheight = 1.0
  ) +
  geom_text(
    data = plot_n_annot,
    aes(x = Time, y = y_n, label = label),
    inherit.aes = FALSE,
    size = 4.0,
    fontface = "bold",
    vjust = 0
  ) +
  geom_text(
    data = pval_annot,
    aes(x = Time, y = y_p, label = label),
    inherit.aes = FALSE,
    size = 4.0,
    fontface = "bold",
    vjust = 0
  ) +
  scale_fill_manual(
    values = c(
      "CR"   = magma_cols[11],
      "VGPR" = magma_cols[8],
      "PR"   = magma_cols[6],
      "SD"   = magma_cols[3],
      "PD"   = magma_cols[1]
    ),
    name = "Hema Response"
  ) +
  facet_wrap(~ productive_IgH, nrow = 1) +
  coord_cartesian(ylim = c(0, y_lim), clip = "off") +
  labs(x = NULL, y = "Percent") +
  theme_classic(base_size = 15) +
  theme(
    strip.text = element_text(face = "bold"),
    axis.text.x = element_text(angle = 0, hjust = 0.5),
    plot.margin = margin(10, 10, 22, 10)
  )

p

ggsave("df_stack_with_patientlevel_wilcox.pdf", plot = p, height = 6, width = 8)
# Out:
# # A tibble: 4 × 7
#   Time   n_LC n_IgH CR_LC_pct CR_IgH_pct  p_value label
#   <fct> <int> <int>     <dbl>      <dbl>    <dbl> <chr>
# 1 3m      407   373      42.5       19.3 3.18e-12 Wilcoxon p = 3.18e-12
# 2 6m      384   356      58.9       36.0 4.78e-10 Wilcoxon p = 4.78e-10
# 3 12m     331   328      71.0       48.5 3.84e- 9 Wilcoxon p = 3.84e-09
# 4 24m     259   260      80.3       57.3 1.62e- 8 Wilcoxon p = 1.62e-08
# plot without title

# %%
library(dplyr)
library(ggplot2)
library(ggpubr)

label_df <- df_sub %>%
  mutate(productive_IgH = factor(productive_IgH)) %>%
  group_by(productive_IgH) %>%
  summarise(
    med = median(dFLC, na.rm = TRUE),
    min_val = min(dFLC, na.rm = TRUE),
    max_val = max(dFLC, na.rm = TRUE),
    y_pos = max(dFLC, na.rm = TRUE) * 1.35,
    label = paste0(
      "Median: ", round(med, 2),
      "\nRange: ", round(min_val, 2), "-", round(max_val, 2)
    ),
    .groups = "drop"
  )

p <- ggplot(df_sub, aes(x = factor(productive_IgH), y = dFLC, fill = factor(productive_IgH))) +
  geom_violin(trim = FALSE, alpha = 1) +
  geom_boxplot(width = 0.1, outlier.shape = NA) +
  geom_text(
    data = label_df,
    aes(x = productive_IgH, y = y_pos, label = label),
    inherit.aes = FALSE,
    size = 3.5,
    fontface = "bold"
  ) +
  scale_fill_manual(values = c("0" = "#1f77b4", "1" = "#ff7f0e")) +
  scale_y_log10() +
  stat_compare_means(method = "wilcox.test") +
  coord_cartesian(clip = "off") +
  theme_classic() +
  theme(plot.margin = margin(10, 20, 10, 10))

p
ggsave("df_sub.pdf", p, height = 5, width = 6)
# Out:
# plot without title

# %%
library(dplyr)
library(stringr)

# extract variables with p < 0.05
sig_vars <- tbl1 %>%
  as_tibble() %>%
  filter(!is.na(p)) %>%
  filter(p < 0.05) %>%
  pull(variable) %>%
  unique()

sig_vars
# Out:
#  [1] "Age≥65"              "productive_IgH"      "t(11;14)"
#  [4] "Cardiac involvement" "Renal involvement"   "dFLC"
#  [7] "dFLC≥180"            "Mayo04"              "Mayo04III"
# [10] "Mayo12"              "Mayo12III_IV"        "NYHA"
# [13] "NT-ProBNP(pg/mL)"    "cTnl (ug/L)"         "cTnI>0.1"
# [16] "LVPW (mm)"           "IVS (mm)"            "24hUP (g)"
# [19] "24hUP≥5g"            "Albumin (g/L)"       "Alb<30"
# [22] ""                    "Ven firstline"

# %%
library(dplyr)
library(tidyr)
library(ggplot2)

# variables of interest
vars <- c(
  "t(11;14)",
  "Cardiac involvement",
  "Mayo04III",
  "Mayo12III_IV"
)

df0 <- uni_df %>%
  filter(!is.na(productive_IgH)) %>%
  dplyr::select(all_of(vars), productive_IgH) %>%
  mutate(
    productive_IgH = as.character(productive_IgH),
    productive_IgH = recode(productive_IgH, "0" = "LC", "1" = "IgH"),
    productive_IgH = factor(productive_IgH, levels = c("LC", "IgH"))
  )

# %%
df_long <- df0 %>%
  pivot_longer(
    cols = all_of(vars),
    names_to = "Variable",
    values_to = "Value"
  ) %>%
  mutate(Value = as.factor(Value))

# %%
plot_df <- df_long %>%
  filter(!is.na(Value)) %>%
  group_by(productive_IgH, Variable, Value) %>%
  summarise(n = n(), .groups = "drop") %>%
  group_by(productive_IgH, Variable) %>%
  mutate(
    total = sum(n),
    percent = n / total * 100
  ) %>%
  ungroup()

# %%
pval_df <- df_long %>%
  filter(!is.na(Value)) %>%
  group_by(Variable) %>%
  summarise(
    p_value = tryCatch(
      fisher.test(table(productive_IgH, Value))$p.value,
      error = function(e) NA_real_
    ),
    .groups = "drop"
  ) %>%
  mutate(
    label = paste0("p = ", signif(p_value, 3))
  )

print(pval_df)
# Out:
# # A tibble: 4 × 3
#   Variable                p_value label
#   <chr>                     <dbl> <chr>
# 1 Cardiac involvement 0.00168     p = 0.00168
# 2 Mayo04III           0.0277      p = 0.0277
# 3 Mayo12III_IV        0.0000405   p = 4.05e-05
# 4 t(11;14)            0.000000700 p = 7e-07

# %%
pval_annot <- bind_rows(
  pval_df %>% mutate(productive_IgH = factor("LC",  levels = c("LC", "IgH"))),
  pval_df %>% mutate(productive_IgH = factor("IgH", levels = c("LC", "IgH")))
)

# %%
y_top <- max(plot_df$percent, na.rm = TRUE)
y_text <- y_top + 10
y_lim  <- y_top + 18

p <- ggplot(plot_df, aes(x = Variable, y = percent, fill = Value)) +
  geom_bar(stat = "identity", color = "black", width = 0.75) +
  geom_text(
    aes(label = sprintf("%.0f%%", percent)),
    position = position_stack(vjust = 0.5),
    size = 3.8,
    fontface = "bold"
  ) +
  geom_text(
    data = pval_annot,
    aes(x = Variable, y = y_text, label = label),
    inherit.aes = FALSE,
    size = 4,
    fontface = "bold"
  ) +
  scale_fill_manual(values = c("firebrick", "steelblue")) +
  facet_wrap(~ productive_IgH, nrow = 1) +
  coord_cartesian(ylim = c(0, y_lim), clip = "off") +
  labs(x = NULL, y = "Percent", fill = NULL) +
  theme_classic(base_size = 15) +
  theme(
    axis.text.x = element_text(angle = 30, hjust = 1),
    strip.text = element_text(face = "bold"),
    plot.margin = margin(10, 10, 20, 10)
  )

p

ggsave("baseline_comparison_productiveIgH.pdf", p, width = 8, height = 6)
# Out:
# plot without title

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(ggpubr)

# -----------------------------------
# variables of interest
# -----------------------------------
cont_vars <- c(
  "BMPC (%)",
  "NT-ProBNP(pg/mL)",
  "LVPW (mm)",
  "IVS (mm)"
)

# -----------------------------------
# prepare data
# -----------------------------------
df_long <- uni_df %>%
  filter(!is.na(productive_IgH)) %>%
  dplyr::select(productive_IgH, all_of(cont_vars)) %>%
  mutate(
    productive_IgH = as.character(productive_IgH),
    productive_IgH = factor(productive_IgH, levels = c("0", "1"))
  ) %>%
  pivot_longer(
    cols = all_of(cont_vars),
    names_to = "Variable",
    values_to = "Value"
  ) %>%
  filter(!is.na(Value))

# nicer facet labels
df_long$Variable <- factor(
  df_long$Variable,
  levels = cont_vars,
  labels = c("BMPC (%)", "NT-ProBNP (pg/mL)", "LVPW (mm)", "IVS (mm)")
)

# -----------------------------------
# median and range labels per group
# -----------------------------------
label_df <- df_long %>%
  group_by(Variable, productive_IgH) %>%
  summarise(
    med = median(Value, na.rm = TRUE),
    min_val = min(Value, na.rm = TRUE),
    max_val = max(Value, na.rm = TRUE),
    y_pos = max(Value, na.rm = TRUE) * 1.28,
    label = paste0(
      "Median: ", signif(med, 3),
      "\nRange: ", signif(min_val, 3), "-", signif(max_val, 3)  # ← FIX HERE
    ),
    .groups = "drop"
  )

# p-value y-position per facet
pval_df <- df_long %>%
  group_by(Variable) %>%
  summarise(
    y_p = max(Value, na.rm = TRUE) * 1.48,
    .groups = "drop"
  )

# -----------------------------------
# plot
# -----------------------------------
p <- ggplot(df_long, aes(x = productive_IgH, y = Value, fill = productive_IgH)) +
  geom_violin(trim = FALSE, alpha = 1, color = "black") +
  geom_boxplot(width = 0.10, outlier.shape = NA) +
  geom_text(
    data = label_df,
    aes(x = productive_IgH, y = y_pos, label = label),
    inherit.aes = FALSE,
    size = 3.2,
    fontface = "bold"
  ) +
  stat_compare_means(
    method = "wilcox.test",
    label = "p.format",
    label.y = NULL
  ) +
  scale_fill_manual(values = c("0" = "#1f77b4", "1" = "#ff7f0e")) +
  scale_x_discrete(labels = c("0" = "LC", "1" = "IgH")) +
  facet_wrap(~ Variable, scales = "free_y", ncol = 2) +
  coord_cartesian(clip = "off") +
  labs(
    x = NULL,
    y = NULL,
    fill = NULL
  ) +
  theme_classic(base_size = 15) +
  theme(
    strip.text = element_text(face = "bold"),
    axis.text.x = element_text(face = "bold"),
    legend.position = "none",
    plot.margin = margin(10, 30, 15, 10)
  )

p

ggsave("productive_IgH_multifacet_violin_median_range.pdf", plot = p, width = 7, height = 8)
# Out:
# plot without title

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(ggpubr)

# -----------------------------------
# derive wall metrics first
# -----------------------------------
uni_df <- uni_df %>%
  mutate(
    wall_mean = (`IVS (mm)` + `LVPW (mm)`) / 2,
    wall_diff = abs(`IVS (mm)` - `LVPW (mm)`)
  )

# -----------------------------------
# variables of interest
# -----------------------------------
cont_vars <- c(
  "BMPC (%)",
  "NT-ProBNP(pg/mL)",
  "wall_mean",
  "wall_diff"
)

# -----------------------------------
# prepare data
# -----------------------------------
df_long <- uni_df %>%
  filter(!is.na(productive_IgH)) %>%
  dplyr::select(productive_IgH, all_of(cont_vars)) %>%
  mutate(
    productive_IgH = as.character(productive_IgH),
    productive_IgH = factor(productive_IgH, levels = c("0", "1"))
  ) %>%
  pivot_longer(
    cols = all_of(cont_vars),
    names_to = "Variable",
    values_to = "Value"
  ) %>%
  filter(!is.na(Value))

# nicer facet labels
df_long$Variable <- factor(
  df_long$Variable,
  levels = cont_vars,
  labels = c(
    "BMPC (%)",
    "NT-ProBNP (pg/mL)",
    "Wall mean (mm)",
    "Wall diff (mm)"
  )
)

# -----------------------------------
# median and range labels per group
# -----------------------------------
label_df <- df_long %>%
  group_by(Variable, productive_IgH) %>%
  summarise(
    med = median(Value, na.rm = TRUE),
    min_val = min(Value, na.rm = TRUE),
    max_val = max(Value, na.rm = TRUE),
    y_pos = max(Value, na.rm = TRUE) * 1.28,
    label = paste0(
      "Median: ", signif(med, 3),
      "\nRange: ", signif(min_val, 3), "-", signif(max_val, 3)
    ),
    .groups = "drop"
  )

# -----------------------------------
# facet-specific p-value positions
# -----------------------------------
pval_df <- df_long %>%
  group_by(Variable) %>%
  summarise(
    y_p = max(Value, na.rm = TRUE) * 1.48,
    .groups = "drop"
  )

# -----------------------------------
# plot
# -----------------------------------
p <- ggplot(df_long, aes(x = productive_IgH, y = Value, fill = productive_IgH)) +
  geom_violin(trim = FALSE, alpha = 1, color = "black") +
  geom_boxplot(width = 0.10, outlier.shape = NA) +
  geom_text(
    data = label_df,
    aes(x = productive_IgH, y = y_pos, label = label),
    inherit.aes = FALSE,
    size = 3.2,
    fontface = "bold"
  ) +
  stat_compare_means(
    method = "wilcox.test",
    label = "p.format"
  ) +
  scale_fill_manual(values = c("0" = "#1f77b4", "1" = "#ff7f0e")) +
  scale_x_discrete(labels = c("0" = "LC", "1" = "IgH")) +
  facet_wrap(~ Variable, scales = "free_y", ncol = 2) +
  coord_cartesian(clip = "off") +
  labs(
    x = NULL,
    y = NULL,
    fill = NULL
  ) +
  theme_classic(base_size = 15) +
  theme(
    strip.text = element_text(face = "bold"),
    axis.text.x = element_text(face = "bold"),
    legend.position = "none",
    plot.margin = margin(10, 30, 15, 10)
  )

p

ggsave("productive_IgH_multifacet_violin_median_range.pdf", plot = p, width = 7, height = 8)
# Out:
# plot without title

# %%
uni_df$productive_IgH<-gsub('0','2',uni_df$productive_IgH)
uni_df$productive_IgH<-gsub('1','0',uni_df$productive_IgH)
uni_df$productive_IgH<-gsub('2','1',uni_df$productive_IgH)

# %%
# ============================================================
# Mediation analysis + Nature-style visualization
# Works directly from med.out produced by mediation::mediate()
# ============================================================

library(dplyr)
library(ggplot2)
library(patchwork)
library(grid)
library(mediation)

# ------------------------------------------------------------
# 1. Run mediation analysis
# ------------------------------------------------------------
uni_df$log_dFLC <- log(uni_df$dFLC)

df2 <- uni_df %>%
  dplyr::select(`Cardiac involvement`, productive_IgH, log_dFLC) %>%
  na.omit()

# make sure treatment is coded consistently
# if productive_IgH is character/factor, this is usually safer:
# df2$productive_IgH <- factor(df2$productive_IgH, levels = c("0", "1"))

med.model <- lm(
  log_dFLC ~ productive_IgH,
  data = df2
)

out.model <- glm(
  `Cardiac involvement` ~ productive_IgH + log_dFLC,
  data = df2,
  family = binomial
)

med.out <- mediate(
  model.m  = med.model,
  model.y  = out.model,
  treat    = "productive_IgH",
  mediator = "log_dFLC",
  boot     = TRUE,
  sims     = 1000
)

summary(med.out)

# ------------------------------------------------------------
# 2. Extract mediation results correctly from med.out
# ------------------------------------------------------------
# For a standard binary treatment mediation analysis, med.out stores:
# ACME = d.avg
# ADE  = z.avg
# Total effect = tau.coef
# Proportion mediated = n.avg
#
# Bootstrap CIs:
# ACME: d.avg.ci
# ADE:  z.avg.ci
# Total: tau.ci
# Prop mediated: n.avg.ci

med_df <- data.frame(
  effect = c("ACME", "ADE", "Total effect", "Prop. mediated"),
  estimate = c(
    unname(med.out$d.avg),
    unname(med.out$z.avg),
    unname(med.out$tau.coef),
    unname(med.out$n.avg)
  ),
  lower = c(
    unname(med.out$d.avg.ci[1]),
    unname(med.out$z.avg.ci[1]),
    unname(med.out$tau.ci[1]),
    unname(med.out$n.avg.ci[1])
  ),
  upper = c(
    unname(med.out$d.avg.ci[2]),
    unname(med.out$z.avg.ci[2]),
    unname(med.out$tau.ci[2]),
    unname(med.out$n.avg.ci[2])
  )
)

eff_df <- med_df %>%
  filter(effect %in% c("ACME", "ADE", "Total effect")) %>%
  mutate(effect = factor(effect, levels = c("Total effect", "ADE", "ACME")))

prop_df <- med_df %>%
  filter(effect == "Prop. mediated")

acme_val  <- med_df$estimate[med_df$effect == "ACME"]
ade_val   <- med_df$estimate[med_df$effect == "ADE"]
total_val <- med_df$estimate[med_df$effect == "Total effect"]
prop_val  <- med_df$estimate[med_df$effect == "Prop. mediated"]

acme_ci  <- med_df %>% filter(effect == "ACME") %>% dplyr::select(lower, upper)
ade_ci   <- med_df %>% filter(effect == "ADE") %>% dplyr::select(lower, upper)
total_ci <- med_df %>% filter(effect == "Total effect") %>% dplyr::select(lower, upper)
prop_ci  <- med_df %>% filter(effect == "Prop. mediated") %>% dplyr::select(lower, upper)

# Optional p-values, if present in med.out
get_safe <- function(x) {
  if (is.null(x)) return(NA_real_)
  unname(x)
}

p_acme <- get_safe(med.out$d.avg.p)
p_ade  <- get_safe(med.out$z.avg.p)
p_tot  <- get_safe(med.out$tau.p)
p_prop <- get_safe(med.out$n.avg.p)

fmt_num <- function(x, digits = 3) sprintf(paste0("%.", digits, "f"), x)
fmt_pct <- function(x, digits = 1) sprintf(paste0("%.", digits, "f%%"), x * 100)
fmt_p <- function(p) {
  if (is.na(p)) return("p = NA")
  if (p < 0.001) return("p < 0.001")
  paste0("p = ", sprintf("%.3f", p))
}

# ------------------------------------------------------------
# 3. Panel A: mediation diagram
# ------------------------------------------------------------
pA <- ggplot() +
  xlim(0, 10) +
  ylim(0, 6.6) +
  theme_void() +

  # nodes
  annotate(
    "label", x = 1.5, y = 3.0, label = "X\nproductive_IgH",
    size = 5.0, label.size = 0.4, fill = "white"
  ) +
  annotate(
    "label", x = 5.0, y = 4.9, label = "M\nlog(dFLC)",
    size = 5.0, label.size = 0.4, fill = "white"
  ) +
  annotate(
    "label", x = 8.5, y = 3.0, label = "Y\nCardiac involvement",
    size = 5.0, label.size = 0.4, fill = "white"
  ) +

  # arrows
  annotate(
    "segment", x = 2.3, xend = 4.1, y = 3.5, yend = 4.5,
    linewidth = 0.8,
    arrow = arrow(length = unit(0.18, "inches"), type = "closed")
  ) +
  annotate(
    "segment", x = 5.9, xend = 7.7, y = 4.5, yend = 3.5,
    linewidth = 0.8,
    arrow = arrow(length = unit(0.18, "inches"), type = "closed")
  ) +
  annotate(
    "segment", x = 2.3, xend = 7.7, y = 2.35, yend = 2.35,
    linewidth = 0.8,
    arrow = arrow(length = unit(0.18, "inches"), type = "closed")
  ) +

  # path labels
  annotate("text", x = 3.2, y = 4.62, label = "a path", size = 4.4) +
  annotate("text", x = 6.8, y = 4.62, label = "b path", size = 4.4) +
  annotate("text", x = 5.0, y = 2.72, label = "Direct effect (ADE)", size = 4.2) +

  # proportion mediated
  annotate(
    "text", x = 5.0, y = 5.95,
    label = paste0(fmt_pct(prop_val, 1), " mediated"),
    size = 4.3, fontface = "bold"
  ) +

  # result summary
  annotate(
    "text", x = 5.0, y = 1.02,
    label = paste0(
      "Indirect effect (ACME) = ", fmt_num(acme_val), 
      " [", fmt_num(acme_ci$lower), ", ", fmt_num(acme_ci$upper), "]\n",
      "Direct effect (ADE) = ", fmt_num(ade_val), 
      " [", fmt_num(ade_ci$lower), ", ", fmt_num(ade_ci$upper), "]\n",
      "Total effect = ", fmt_num(total_val), 
      " [", fmt_num(total_ci$lower), ", ", fmt_num(total_ci$upper), "]\n",
      "Proportion mediated = ", fmt_pct(prop_val, 1),
      " [", fmt_pct(prop_ci$lower, 1), ", ", fmt_pct(prop_ci$upper, 1), "]"
    ),
    size = 4.0, lineheight = 1.15
  ) +

  annotate(
    "text", x = 0.2, y = 6.45, label = "A",
    hjust = 0, vjust = 1, size = 7, fontface = "bold"
  )

# ------------------------------------------------------------
# 4. Panel B: forest plot for ACME/ADE/Total
# ------------------------------------------------------------
label_df <- eff_df %>%
  mutate(
    label_txt = sprintf("%.3f", estimate),
    label_x = min(lower, na.rm = TRUE) - 0.06 * diff(range(c(lower, upper), na.rm = TRUE))
  )

pB <- ggplot(eff_df, aes(x = estimate, y = effect)) +
  geom_vline(xintercept = 0, linetype = "dashed", linewidth = 0.5, color = "grey50") +
  geom_errorbarh(aes(xmin = lower, xmax = upper), height = 0.16, linewidth = 0.8) +
  geom_point(size = 3.2, shape = 21, fill = "black", color = "black", stroke = 0.6) +
  geom_text(
    data = label_df,
    aes(x = label_x, y = effect, label = label_txt),
    inherit.aes = FALSE,
    hjust = 1,
    size = 3.8
  ) +
  scale_x_continuous(expand = expansion(mult = c(0.20, 0.08))) +
  labs(x = "Effect size (95% bootstrap CI)", y = NULL) +
  theme_classic(base_size = 13) +
  theme(
    axis.text.y = element_text(size = 12, color = "black"),
    axis.text.x = element_text(size = 11, color = "black"),
    axis.title.x = element_text(size = 12),
    plot.margin = margin(10, 15, 10, 10)
  ) +
  annotate(
    "text", x = -Inf, y = Inf, label = "B",
    hjust = -0.7, vjust = 1.7, size = 7, fontface = "bold"
  )

# ------------------------------------------------------------
# 5. Panel C: proportion mediated with correct CI scale
# ------------------------------------------------------------
ymin_c <- min(0, prop_df$lower, prop_df$estimate, na.rm = TRUE)
ymax_c <- max(0, prop_df$upper, prop_df$estimate, na.rm = TRUE)
ypad_c <- 0.08 * (ymax_c - ymin_c)
if (ypad_c == 0) ypad_c <- 0.1

pC <- ggplot(prop_df, aes(x = effect, y = estimate)) +
  geom_col(width = 0.52, fill = "grey20") +
  geom_errorbar(aes(ymin = lower, ymax = upper), width = 0.12, linewidth = 0.8) +
  geom_hline(yintercept = 0, linewidth = 0.5) +
  coord_cartesian(ylim = c(ymin_c - ypad_c, ymax_c + ypad_c)) +
  labs(x = NULL, y = "Proportion mediated") +
  theme_classic(base_size = 13) +
  theme(
    axis.text.x = element_text(size = 11, color = "black"),
    axis.text.y = element_text(size = 11, color = "black"),
    axis.title.y = element_text(size = 12),
    plot.margin = margin(10, 10, 10, 10)
  ) +
  annotate(
    "text", x = 1, y = prop_df$estimate + 0.04 * (ymax_c - ymin_c + 1e-8),
    label = fmt_pct(prop_df$estimate, 1),
    size = 4
  ) +
  annotate(
    "text", x = -Inf, y = Inf, label = "C",
    hjust = -0.7, vjust = 1.7, size = 7, fontface = "bold"
  )

# ------------------------------------------------------------
# 6. Combine panels
# ------------------------------------------------------------
final_plot <- pA + pB
  plot_annotation(
    title = "Causal mediation analysis",
    theme = theme(
      plot.title = element_text(size = 15, face = "bold", hjust = 0.5)
    )
  )

final_plot

# ------------------------------------------------------------
# 7. Save
# ------------------------------------------------------------
ggsave(
  "mediation_nature_style.pdf",
  final_plot,
  width = 10,
  height = 5,
  useDingbats = FALSE
)

ggsave(
  "mediation_nature_style.png",
  final_plot,
  width = 10,
  height = 5,
  dpi = 400
)
# Out:
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:MASS’:
#
#     area
#
#
# Running nonparametric bootstrap
# Causal Mediation Analysis
#
# Nonparametric Bootstrap Confidence Intervals with the Percentile Method
#
#                           Estimate 95% CI Lower 95% CI Upper p-value
# ACME (control)            0.066797     0.042781     0.093309  <2e-16 ***
# ACME (treated)            0.063243     0.039666     0.091516  <2e-16 ***
# ADE (control)             0.026759    -0.034994     0.089239   0.482
# ADE (treated)             0.023205    -0.030747     0.078924   0.482
# Total Effect              0.090003     0.029211     0.149382   0.002 **
# Prop. Mediated (control)  0.742172     0.429838     1.919675   0.002 **
# Prop. Mediated (treated)  0.702685     0.364451     2.120338   0.002 **
# ACME (average)            0.065020     0.041298     0.091865  <2e-16 ***
# ADE (average)             0.024982    -0.032872     0.083427   0.482
# ...

# %%
# =========================
# 0) Load packages
# =========================
suppressPackageStartupMessages({
  library(dplyr)
  library(survival)
  library(survminer)
  library(ggplot2)
})

# =========================
# 1) Clean column names
# =========================
dat <- uni_df %>%
  rename(
    cardiac = `Cardiac involvement`,
    dflc = dFLC,
    cr_3m = `3m_cr_only`,
    sex = Sex,
    age = Age
  )

# Check
colnames(dat)

# =========================
# 2) Make variables usable
# =========================
dat <- dat %>%
  mutate(
    productive_IgH = as.character(productive_IgH),
    cr_3m = as.character(cr_3m),
    sex = factor(sex),
    cardiac = as.character(cardiac),
    dflc = suppressWarnings(as.numeric(dflc)),
    age = suppressWarnings(as.numeric(age)),
    os_time = suppressWarnings(as.numeric(os_time)),
    os_event = suppressWarnings(as.numeric(os_event))
  )

# Label productive_IgH
# 0 = LC-only
# 1 = LC-with-IgH
if (all(na.omit(unique(dat$productive_IgH)) %in% c("0", "1"))) {
  dat <- dat %>%
    mutate(
      productive_IgH = factor(
        productive_IgH,
        levels = c("1", "0"),
        labels = c("LC-with-IgH", "LC-only")
      )
    )
} else {
  dat <- dat %>% mutate(productive_IgH = factor(productive_IgH))
}

# Label CR
if (all(na.omit(unique(dat$cr_3m)) %in% c("0", "1"))) {
  dat <- dat %>%
    mutate(
      cr_3m = factor(
        cr_3m,
        levels = c("0", "1"),
        labels = c("No CR at 3m", "CR at 3m")
      )
    )
} else {
  dat <- dat %>% mutate(cr_3m = factor(cr_3m))
}

# Label cardiac involvement
if (all(na.omit(unique(dat$cardiac)) %in% c("0", "1"))) {
  dat <- dat %>%
    mutate(
      cardiac = factor(
        cardiac,
        levels = c("0", "1"),
        labels = c("No cardiac involvement", "Cardiac involvement")
      )
    )
} else {
  dat <- dat %>% mutate(cardiac = factor(cardiac))
}

# =========================
# 3) Remove rows missing survival data / key vars
# =========================
dat_surv <- dat %>%
  dplyr::filter(
    !is.na(os_time),
    !is.na(os_event),
    !is.na(productive_IgH),
    !is.na(cr_3m)
  )

# Check event coding
table(dat_surv$os_event, useNA = "ifany")
table(dat_surv$productive_IgH, useNA = "ifany")
table(dat_surv$cr_3m, useNA = "ifany")

# =========================
# 4) Kaplan-Meier curves
# =========================

# 4A. KM by productive_IgH subgroup
fit_os_igh <- survfit(
  Surv(os_time, os_event) ~ productive_IgH,
  data = dat_surv
)

p1 <- ggsurvplot(
  fit_os_igh, data = dat_surv,
  title = "OS by IgH subgroup",
  xlab = "Time (months)", ylab = "Probability",
  conf.int = FALSE, pval = TRUE,
  risk.table = TRUE,
  risk.table.height = 0.25,
  risk.table.y.text = FALSE,
  risk.table.fontsize = 4,
  legend = "right",
  break.time.by = 24,
  ggtheme = theme_classic(base_size = 14)
)

print(p1)

# 4B. KM by CR in all patients
fit_os_cr_all <- survfit(
  Surv(os_time, os_event) ~ cr_3m,
  data = dat_surv
)

p2 <- ggsurvplot(
  fit_os_cr_all, data = dat_surv,
  title = "OS by 3-month CR in all patients",
  xlab = "Time (months)", ylab = "Probability",
  conf.int = FALSE, pval = TRUE,
  risk.table = TRUE,
  risk.table.height = 0.25,
  risk.table.y.text = FALSE,
  risk.table.fontsize = 4,
  legend = "right",
  break.time.by = 24,
  ggtheme = theme_classic(base_size = 14)
)

print(p2)

# 4C. KM by CR within LC-only
dat_lc_only <- dat_surv %>%
  dplyr::filter(productive_IgH == "LC-only")

fit_lc_only <- survfit(
  Surv(os_time, os_event) ~ cr_3m,
  data = dat_lc_only
)

p3 <- ggsurvplot(
  fit_lc_only, data = dat_lc_only,
  title = "OS by 3-month CR in LC-only",
  xlab = "Time (months)", ylab = "Probability",
  conf.int = FALSE, pval = TRUE,
  risk.table = TRUE,
  risk.table.height = 0.25,
  risk.table.y.text = FALSE,
  risk.table.fontsize = 4,
  legend = "right",
  break.time.by = 24,
  ggtheme = theme_classic(base_size = 14)
)

print(p3)

# 4D. KM by CR within LC-with-IgH
dat_lc_igh <- dat_surv %>%
  dplyr::filter(productive_IgH == "LC-with-IgH")

fit_lc_igh <- survfit(
  Surv(os_time, os_event) ~ cr_3m,
  data = dat_lc_igh
)

p4 <- ggsurvplot(
  fit_lc_igh, data = dat_lc_igh,
  title = "OS by 3-month CR in LC-with-IgH",
  xlab = "Time (months)", ylab = "Probability",
  conf.int = FALSE, pval = TRUE,
  risk.table = TRUE,
  risk.table.height = 0.25,
  risk.table.y.text = FALSE,
  risk.table.fontsize = 4,
  legend = "right",
  break.time.by = 24,
  ggtheme = theme_classic(base_size = 14)
)

print(p4)

# =========================
# 5) Log-rank tests
# =========================

cat("\n=== Overall subgroup difference ===\n")
print(survdiff(Surv(os_time, os_event) ~ productive_IgH, data = dat_surv))

cat("\n=== CR effect overall ===\n")
print(survdiff(Surv(os_time, os_event) ~ cr_3m, data = dat_surv))

cat("\n=== CR effect within LC-only ===\n")
print(survdiff(Surv(os_time, os_event) ~ cr_3m, data = dat_lc_only))

cat("\n=== CR effect within LC-with-IgH ===\n")
print(survdiff(Surv(os_time, os_event) ~ cr_3m, data = dat_lc_igh))

# =========================
# 6) Univariable Cox models
# =========================

cox_uni_igh <- coxph(
  Surv(os_time, os_event) ~ productive_IgH,
  data = dat_surv
)

cox_uni_cr <- coxph(
  Surv(os_time, os_event) ~ cr_3m,
  data = dat_surv
)

cox_uni_cardiac <- coxph(
  Surv(os_time, os_event) ~ cardiac,
  data = dat_surv
)

cox_uni_dflc <- coxph(
  Surv(os_time, os_event) ~ dflc,
  data = dat_surv
)

summary(cox_uni_igh)
summary(cox_uni_cr)
summary(cox_uni_cardiac)
summary(cox_uni_dflc)

# =========================
# 7) Multivariable Cox model
# =========================
# Use LC-with-IgH as reference
# Use No CR at 3m as reference
# Use No cardiac involvement as reference if available

dat_cox <- dat_surv

if ("LC-with-IgH" %in% levels(dat_cox$productive_IgH)) {
  dat_cox$productive_IgH <- relevel(dat_cox$productive_IgH, ref = "LC-with-IgH")
}

if ("No CR at 3m" %in% levels(dat_cox$cr_3m)) {
  dat_cox$cr_3m <- relevel(dat_cox$cr_3m, ref = "No CR at 3m")
}

if ("No cardiac involvement" %in% levels(dat_cox$cardiac)) {
  dat_cox$cardiac <- relevel(dat_cox$cardiac, ref = "No cardiac involvement")
}

cox_multi <- coxph(
  Surv(os_time, os_event) ~ productive_IgH + cardiac + dflc + cr_3m + sex + age,
  data = dat_cox
)

summary(cox_multi)

# =========================
# 8) Hazard ratio table
# =========================
cox_sum <- summary(cox_multi)

hr_table <- data.frame(
  Variable = rownames(cox_sum$coefficients),
  HR = cox_sum$coefficients[, "exp(coef)"],
  Lower95 = cox_sum$conf.int[, "lower .95"],
  Upper95 = cox_sum$conf.int[, "upper .95"],
  Pvalue = cox_sum$coefficients[, "Pr(>|z|)"],
  row.names = NULL,
  check.names = FALSE
)

print(hr_table)

hr_table_fmt <- hr_table %>%
  mutate(
    HR_CI = sprintf("%.2f (%.2f-%.2f)", HR, Lower95, Upper95),
    Pvalue = signif(Pvalue, 3)
  ) %>%
  dplyr::select(Variable, HR_CI, Pvalue)

print(hr_table_fmt, row.names = FALSE)

# =========================
# 8B) Forest plot
# =========================
plot_df <- hr_table %>%
  mutate(
    Label = sprintf("%.2f (%.2f-%.2f)", HR, Lower95, Upper95),
    Ptxt = ifelse(Pvalue < 0.001, "<0.001", sprintf("%.3f", Pvalue)),
    Variable = gsub("productive_IgH", "IgH subgroup: ", Variable),
    Variable = gsub("cardiac", "Cardiac: ", Variable),
    Variable = gsub("cr_3m", "3m CR: ", Variable),
    Variable = gsub("sex", "Sex: ", Variable),
    Variable = gsub("dflc", "dFLC", Variable),
    Variable = gsub("age", "Age", Variable)
  ) %>%
  mutate(
    Variable = factor(Variable, levels = rev(Variable))
  )

xmax <- max(plot_df$Upper95, na.rm = TRUE)
xmin <- min(plot_df$Lower95, na.rm = TRUE)

ggplot(plot_df, aes(x = HR, y = Variable)) +
  geom_point(size = 3) +
  geom_errorbarh(aes(xmin = Lower95, xmax = Upper95), height = 0.2) +
  geom_vline(xintercept = 1, linetype = 2) +
  scale_x_log10(
    limits = c(min(0.5, xmin * 0.9), max(2, xmax * 2.2))
  ) +
  geom_text(aes(x = xmax * 1.35, label = Label), hjust = 0, size = 4) +
  geom_text(aes(x = xmax * 2.0, label = Ptxt), hjust = 0, size = 4) +
  annotate("text", x = xmax * 1.35, y = length(levels(plot_df$Variable)) + 0.8,
           label = "HR (95% CI)", hjust = 0, size = 4.2) +
  annotate("text", x = xmax * 2.0, y = length(levels(plot_df$Variable)) + 0.8,
           label = "P", hjust = 0, size = 4.2) +
  coord_cartesian(clip = "off") +
  labs(
    title = "Multivariable Cox model for OS",
    x = "Hazard ratio (log scale)",
    y = NULL
  ) +
  theme_classic(base_size = 14) +
  theme(
    plot.margin = margin(5.5, 120, 5.5, 5.5)
  )

# =========================
# 9) Test proportional hazards assumption
# =========================
ph_test <- cox.zph(cox_multi)
print(ph_test)
plot(ph_test)

# =========================
# 10) Optional interaction model
# =========================
cox_interaction <- coxph(
  Surv(os_time, os_event) ~ productive_IgH * cr_3m + cardiac + dflc + sex + age,
  data = dat_cox
)

summary(cox_interaction)
anova(cox_multi, cox_interaction, test = "LRT")
# Out:
#  [1] "ID"                   "sex"                  "age"
#  [4] "Age≥65"               "AL isotype (1=λ)"     "Sx_Dx"
#  [7] "Involved Organs (n)"  "cardiac"              "Renal involvement"
# [10] "Hepatic involvement"  "treat"                "t(11;14)"
# [13] "cTnl (ug/L)"          "NT-ProBNP(pg/mL)"     "24hUP (g)"
# [16] "eGFR"                 "Albumin (g/L)"        "IVS (mm)"
# [19] "LVPW (mm)"            "EF (%)"               "BNP (ng/L)"
# [22] "dflc"                 "BMPC (%)"             "Mayo04"
# [25] "Mayo12"               "NYHA"                 "productive_IgH"
# [28] "3m HR"                "6m HR"                "12m HR"
# [31] "24m HR"               "best_hema_resp"       "best_hema_resp_time"
# [34] "hema_or"              "hema_vgpr"            "hema_cr_only"
# [37] "cardiac_12m"          "cardiac_24m"          "os_time"
# [40] "os_event"             "TTNT_time"            "TTNT_event"
# [43] "Dara firstline"       "Bort firstline"       "Ven firstline"
# ...

# %%
# =========================
# 8B) Forest plot for multivariable Cox model
# =========================
plot_df <- hr_table %>%
  mutate(
    Variable = gsub("productive_IgH", "IgH subgroup: ", Variable),
    Variable = gsub("cardiac", "Cardiac: ", Variable),
    Variable = gsub("cr_3m", "3m CR: ", Variable),
    Variable = gsub("sex", "Sex: ", Variable),
    Variable = gsub("dflc", "dFLC", Variable),
    Variable = gsub("age", "Age", Variable)
  ) %>%
  mutate(
    Variable = factor(Variable, levels = rev(Variable)),
    sig = Pvalue < 0.05
  )

ggplot(plot_df, aes(x = HR, y = Variable)) +
  geom_point(size = 3) +
  geom_errorbarh(aes(xmin = Lower95, xmax = Upper95), height = 0.2) +
  geom_vline(xintercept = 1, linetype = 2) +
  scale_x_log10() +
  labs(
    title = "Multivariable Cox model for OS",
    x = "Hazard ratio (log scale)",
    y = NULL
  ) +
  theme_classic(base_size = 14)
# Out:
# plot without title

# %%
plot_df2 <- hr_table %>%
  mutate(
    Label = sprintf("%.2f (%.2f-%.2f)", HR, Lower95, Upper95),
    Ptxt = ifelse(Pvalue < 0.001, "<0.001", sprintf("%.3f", Pvalue)),
    Variable = gsub("productive_IgH", "IgH subgroup: ", Variable),
    Variable = gsub("cardiac", "Cardiac: ", Variable),
    Variable = gsub("cr_3m", "3m CR: ", Variable),
    Variable = gsub("sex", "Sex: ", Variable),
    Variable = gsub("dflc", "dFLC", Variable),
    Variable = gsub("age", "Age", Variable)
  ) %>%
  mutate(
    Variable = factor(Variable, levels = rev(Variable))
  )

xmax <- max(plot_df2$Upper95, na.rm = TRUE)
xmin <- min(plot_df2$Lower95, na.rm = TRUE)

ggplot(plot_df2, aes(x = HR, y = Variable)) +
  geom_point(size = 3) +
  geom_errorbarh(aes(xmin = Lower95, xmax = Upper95), height = 0.2) +
  geom_vline(xintercept = 1, linetype = 2) +
  scale_x_log10(
    limits = c(min(0.5, xmin * 0.9), max(2, xmax * 2.2))
  ) +
  geom_text(aes(x = xmax * 1.35, label = Label), hjust = 0, size = 4) +
  geom_text(aes(x = xmax * 2.0, label = Ptxt), hjust = 0, size = 4) +
  annotate("text", x = xmax * 1.35, y = length(levels(plot_df2$Variable)) + 0.8,
           label = "HR (95% CI)", hjust = 0, size = 4.2) +
  annotate("text", x = xmax * 2.0, y = length(levels(plot_df2$Variable)) + 0.8,
           label = "P", hjust = 0, size = 4.2) +
  coord_cartesian(clip = "off") +
  labs(
    title = "Multivariable Cox model for OS",
    x = "Hazard ratio (log scale)",
    y = NULL
  ) +
  theme_classic(base_size = 14) +
  theme(
    plot.margin = margin(5.5, 120, 5.5, 5.5)
  )
# Out:
# plot without title
